# %%
# %pip install torch numpy transformers datasets tiktoken wandb tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
print(torch.__version__)
# Out:
# 2.0.1+cu118

# %%
from model import GPT, GPTConfig
model_config = GPTConfig()
model = GPT(model_config)

print(model.parameters())

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-dbef26643e69> in <cell line: 1>()
# ----> 1 from model import GPT, GPTConfig
#       2 model_config = GPTConfig()
#       3 model = GPT(model_config)
#       4
#       5 print(model.parameters())
#
# ModuleNotFoundError: No module named 'model'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab\ Notebooks/nanoGPT
# Out:
# /content/drive/MyDrive/Colab Notebooks/nanoGPT

# %%
# !ls
# Out:
# assets	  configurator.py  model.py	README.md	    train.py		      wizerr.ipynb
# bench.py  data		   out-wizerr	sample.py	    train_wizerr.py
# config	  LICENSE	   __pycache__	scaling_laws.ipynb  transformer_sizing.ipynb

# %%
# !python data/wizerr_data/prepare.py
# Out:
# 23388739
# train has 5,407,830 tokens
# val has 545,002 tokens
# C:\Users\micha\AppData\Roaming\Python\Python311\site-packages\datasets\load.py:1461: FutureWarning: The repository for DFKI-SLT/fabner contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/DFKI-SLT/fabner
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
# !python train_wizerr.py config/finetune_wizerr.py --compile=False --learning_rate=3e-6
# Out:
# Overriding config with config/finetune_wizerr.py:
# import time
#
# out_dir = 'out-wizerr'
# eval_interval = 5
# eval_iters = 40
# wandb_log = False # feel free to turn on
# wandb_project = 'shakespeare'
# wandb_run_name = 'ft-' + str(time.time())
#
# dataset = 'wizerr_data'
# init_from = 'gpt2-medium' # this is the largest GPT-2 model
#
# # only save checkpoints if the validation loss improves
# always_save_checkpoint = False
#
# # the number of examples per iter:
# # 1 batch_size * 32 grad_accum * 1024 tokens = 32,768 tokens/iter
# # shakespeare has 1,860,788 tokens, so 1 epoch ~=  56.7 iters
# batch_size = 1
# gradient_accumulation_steps = 32
# max_iters = 50
#
# # finetune at constant LR
# learning_rate = 3e-5
# decay_lr = False
#
# Overriding: compile = False
# Overriding: learning_rate = 3e-06
# tokens per iteration will be: 32,768
# Initializing from OpenAI GPT-2 weights: gpt2-medium
# loading weights from pretrained gpt: gpt2-medium
# ...

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.9.3
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albumentations                   1.3.1
# altair                           4.2.2
# annotated-types                  0.6.0
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.5.0
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.0
# attrs                            23.2.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.14.0
# ...

# %%
! python sample.py \
    --init_from=gpt2-medium \
    --start="Can you explain some terminology specific to semi conductor manufacturing?" \
    --num_samples=1 --max_new_tokens=400
# Out:
# Overriding: init_from = gpt2-medium
# Overriding: start = Can you explain some terminology specific to semi conductor manufacturing?
# Overriding: num_samples = 1
# Overriding: max_new_tokens = 400
# loading weights from pretrained gpt: gpt2-medium
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 353.77M
# No meta.pkl found, assuming GPT-2 encodings...
# Can you explain some terminology specific to semi conductor manufacturing?
#
# ...

# %%
! python sample.py \
    --init_from=resume \
    --out_dir='out-wizerr' \
    --start="Can you explain some terminology specific to semi conductor manufacturing?" \
    --num_samples=1 --max_new_tokens=400
# Out:
# Overriding: init_from = resume
# Overriding: out_dir = out-wizerr
# Overriding: start = Can you explain some terminology specific to semi conductor manufacturing?
# Overriding: num_samples = 1
# Overriding: max_new_tokens = 400
# number of parameters: 353.77M
# No meta.pkl found, assuming GPT-2 encodings...
# Can you explain some terminology specific to semi conductor manufacturing?
#
# ...
