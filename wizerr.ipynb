# %%
# %pip install torch numpy transformers datasets tiktoken wandb tqdm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 43.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 46.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 50.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 52.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 75.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.2.1+cu121

# %%
from model import GPT, GPTConfig
model_config = GPTConfig()
model = GPT(model_config)

print(model.parameters())

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-dbef26643e69> in <cell line: 1>()
# ----> 1 from model import GPT, GPTConfig
#       2 model_config = GPTConfig()
#       3 model = GPT(model_config)
#       4
#       5 print(model.parameters())
#
# ModuleNotFoundError: No module named 'model'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab\ Notebooks/nanoGPT
# Out:
# /content/drive/MyDrive/Colab Notebooks/nanoGPT

# %%
# !ls
# Out:
# assets	  configurator.py  model.py	README.md	    train.py		      wizerr.ipynb
# bench.py  data		   out-wizerr	sample.py	    train_wizerr.py
# config	  LICENSE	   __pycache__	scaling_laws.ipynb  transformer_sizing.ipynb

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.9.3
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albumentations                   1.3.1
# altair                           4.2.2
# annotated-types                  0.6.0
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.5.0
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.0
# attrs                            23.2.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.14.0
# ...

# %%
# !python train_wizerr.py config/finetune_wizerr.py --compile=False
# Out:
# Overriding config with config/finetune_wizerr.py:
# import time
#
# out_dir = 'out-wizerr'
# eval_interval = 5
# eval_iters = 40
# wandb_log = False # feel free to turn on
# wandb_project = 'shakespeare'
# wandb_run_name = 'ft-' + str(time.time())
#
# dataset = 'wizerr_data'
# init_from = 'gpt2-medium' # this is the largest GPT-2 model
#
# # only save checkpoints if the validation loss improves
# always_save_checkpoint = False
#
# # the number of examples per iter:
# # 1 batch_size * 32 grad_accum * 1024 tokens = 32,768 tokens/iter
# # shakespeare has 1,860,788 tokens, so 1 epoch ~=  56.7 iters
# batch_size = 1
# gradient_accumulation_steps = 32
# max_iters = 50
#
# # finetune at constant LR
# learning_rate = 3e-5
# decay_lr = False
#
# Overriding: compile = False
# tokens per iteration will be: 32,768
# Initializing from OpenAI GPT-2 weights: gpt2-medium
# loading weights from pretrained gpt: gpt2-medium
# forcing vocab_size=50257, block_size=1024, bias=True
# ...

# %%
! python sample.py \
    --init_from=gpt2-medium \
    --start="What are important aspects to semi conductor manufacturing?" \
    --num_samples=5 --max_new_tokens=200
# Out:
# Overriding: init_from = gpt2-medium
# Overriding: start = What are important aspects to semi conductor manufacturing?
# Overriding: num_samples = 5
# Overriding: max_new_tokens = 200
# loading weights from pretrained gpt: gpt2-medium
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 353.77M
# No meta.pkl found, assuming GPT-2 encodings...
# What are important aspects to semi conductor manufacturing?
#
# One of the most important aspects we need to consider is how to design and build semi conductor components that are critical for high speed transmission under load. If we can test these components using high-speed test equipment that can provide the required reliability and performance without breaking the bank, then we will be able to manufacture these components to withstand the rigors of a wide range of operating environments.
#
# ...

# %%
! python sample.py \
    --init_from=resume \
    --out_dir='out-wizerr' \
    --start="What are important aspects to semi conductor manufacturing?" \
    --num_samples=5 --max_new_tokens=200
